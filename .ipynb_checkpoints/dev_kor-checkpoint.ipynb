# %%
# ! pip install newsapi-python

# %%
import os

from newsapi import NewsApiClient
from tqdm import tqdm

from keybert import KeyBERT

import pandas as pd
import pickle

from itertools import chain
from collections import Counter

import datetime as DT

# %%
# api request를 정하는 부분으로 신중하게 확인할
from_date = '2023-05-22'
to_date = '2023-05-29'
query = '금융 OR 은행 OR 경제 OR 지속가능성'
pages = range(1,6) # 무료 api는 일일당 5page가 최대.

# %%
# 환경 설정
cwd = os.getcwd()
main_path = cwd + '/' + query 

def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)

createFolder(main_path)
createFolder(main_path + '/' + 'dataByDate')

# %%
# Out:
# '20230522'

# %%
# 데이터 수집(download)

raw = pd.read_excel(main_path + '/' + 'dataByDate/' + 'NewsResult_{}-{}.xlsx'.format(from_date.replace('-',''),to_date.replace('-','')) )
# Out:
# C:\Users\NH\anaconda3\lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
raw
# Out:
#              뉴스 식별자        일자     언론사     기고자  \
# 0      7.101201e+06  20230529  디지털타임스     이윤희
# 1      1.400351e+06  20230529    중도일보  이인국 기자
# 2      1.400351e+06  20230529    중도일보  이인국 기자
# 3      1.400351e+06  20230529    중도일보  이인국 기자
# 4      2.100601e+06  20230529    한국경제     고윤상
# ...             ...       ...     ...     ...
# 13112  1.200101e+06  20230522    경기일보     손사라
# 13113  1.200201e+06  20230522    경인일보     백효은
# 13114  1.601101e+06  20230522    전북일보     육경근
# 13115  1.400351e+06  20230522    중도일보  이승주 기자
# 13116  1.400351e+06  20230522    중도일보  이창식 기자
#
#                                                 제목     통합 분류1          통합 분류2  \
# 0       금융과 금융을 잇다...코스콤 자본시장중계 STP-HUB 차세대 시스템 가동  IT_과학>모바일        경제>증권_증시
# 1          용인시의회 신현녀 의원, '시 통합 물관리 기본조례 개정 정책' 간담회      지역>경남           지역>대구
# 2               용인시정연구원, IT/SW 차세대 밸리 3대 전략 보고서 발간      지역>경기           지역>대전
# 3                  하남시의회 문화예술 연구단체, 지역 대표축제 키우기 논의   문화>요리_여행        문화>전시_공연
# 4      [수능에 나오는 경제 금융] 인구 줄면 경기도 침체 로봇 AI로 생산성 높여야    경제>경제일반   IT_과학>IT_과학일반
# ...                                            ...        ...             ...
# 13112  문미선 세종대왕 봉사단 회장 “이주여성과 동행하며 온기로 언어 장벽 녹일 것”      사회>여성        사회>교육_시험
# 13113               인천시의회 '전세사기 대책 결의안' 보류 피해자들 분통   정치>국회_정당        정치>행정_자치
# 13114              전북대 왕의지밀, 교직원 복지 증진 서비스 홍보 업무협약      지역>충남           지역>제주
# 13115            함평군-체코 리베레츠시, 우호 결연 문화예술 우호 교류 협약      지역>충남        문화>전시_공연
# 13116                         화순군, 하천점용료 25% 감면 시행      지역>충북           지역>경기
#
#            통합 분류3 사건/사고 분류1 사건/사고 분류2 사건/사고 분류3  \
# 0       경제>금융_재테크       NaN       NaN       NaN
# 1           지역>경기       NaN       NaN       NaN
# 2           지역>대구       NaN       NaN       NaN
# 3           지역>제주       NaN       NaN       NaN
# 4         국제>국제일반       NaN       NaN       NaN
# ...           ...       ...       ...       ...
# 13112      사회>장애인       NaN       NaN       NaN
# 13113       정치>선거       NaN       NaN       NaN
# 13114       지역>대전       NaN       NaN       NaN
# 13115       지역>대전       NaN       NaN       NaN
# 13116       사회>환경       NaN       NaN       NaN
#
#                                                       인물  \
# 0                                                    황선정
# 1      박희정,김희영,이윤미,황미상,윤원균,안치용,신민석,이교우,최경영,유진선,김진석,박병...
# 2                                                    김의성
# 3                                        정혜영,오지연,정병용,오승철
# 4                                            토머스,맬서스,고윤상
# ...                                                  ...
# 13112                                               세종대왕
# 13113                                         김대영,재석,안상미
# 13114                                             제공,손의준
# 13115                                        크리스탈,이상익,이반
# 13116                                                NaN
#
#                                                       위치  \
# 0                                           고성,뉴노멀,중계,선진
# 1                  마북동,동백1동,구성동,한국LID협회,신현녀,동백2동,용인시,수도권
# 2       테크노밸리,고성,수원시,임계,신성,판교,선진,판교테크노밸리,성남시,정주,상업지구,용인시
# 3                                     함평 나비축제,하남시,하남문화재단
# 4                                           미국,중국,한국,경기도
# ...                                                  ...
# 13112                                     화성시,문미선,한국,경기도
# 13113                                        신성영,미추홀구,인천
# 13114                                                NaN
# 13115  우호,세베라첵,대전,함평군,체코,대한민국,함평,랑그르,2022국향대전,전남,세베라첵...
# 13116                                      전경전남,화순군,화순군청
#
#                                                       기관  \
# 0                           국민연,유일,코스콤,Fina,STP-HUB,토큰증권
# 1      부산대학교,경제환경위원장,탄소중립연구소,최경영 저영향개발협회,더불어민주당,경제환경위...
# 2         용인시정연구원(원장,용인특례시,용인,용인시정연구원,YRI Insight,한국,용인시
# 3                                          문화정책,유일,하남시의회
# 4                              한국경제신문,미국,S&P500,AI,한국,NI
# ...                                                  ...
# 13112                                                봉사단
# 13113                               정부,청구,국회,피해대책위,인천시의회
# 13114                                     전주,전북대,왕,전북대학교
# 13115                       문화교류,함평군,자원,동유럽,체코 대표 청소년합창단
# 13116                                             화순군,화군
#
#                                                      키워드  \
# 0      금융,금융,코스콤,자본,시장,중계,STP-HUB,차세대,가동,중계허브,자본,시장,중...
# 1      의원,용인시의회,신현녀,통합,물관리,기본,조례,개정,정책,간담회,의원,용인,특례,의...
# 2      용인시정연구원,SW,차세대,밸리,전략,보고서,발간,용인시정연구원,원장,이상대,제70...
# 3      연구단체,하남시,의회,문화,예술,단체,지역,대표,축제,논의,24일,발굴,하남시의회,...
# 4      인구,경기도,침체,로봇,AI,생산성,요즘,한국,저출산,사회문제,저출산,인구,구조,변...
# ...                                                  ...
# 13112  이주여성,문미선,세종대왕,봉사단,회장,이주,여성,동행,온기,언어,장벽,문미선,세종대...
# 13113  인천시,의회,전세,사기,대책,결의안,보류,피해자,분통,인천시의회,본회의,결의안,주택...
# 13114  전북대,왕의지밀,증진,교직원,복지,서비스,홍보,업무,협약,전북대학교,한옥,호텔,왕의...
# 13115  함평군,체코,리베레츠시,우호,결연,문화예술,협약,우호,교류,2022국향,대전,세베라...
# 13116  화순군,하천점,용료,25%,감면,시행,경감,민생경제,활력,활력,화순군,화순군청,전경...
#
#                                        특성추출(가중치순 상위 50개)  \
# 0             코스콤,고객사,실시간,국민연금,차세대,증권사,고성능,미들웨어,황선정,중계허브
# 1      신현녀,간담회,최경영,물관리,용인시,물순환,연구원,신민석,문제점,도시침수,필요성,동...
# 2            용인,sw,클러스터,차세대,매출액,대기업,용인시,판교,보고서,이슈리포트,김의성
# 3      하남시,하남시의회,정병용,연구단체,관계자,간담회,하남문화재단,함평,산천어,대표의원,...
# 4      베이비붐,제조업,미국,한국,인구구조,저성장,ai,오너스,인플레이션,자동화,저출산,경...
# ...                                                  ...
# 13112  이주여성,지역사회,문미선,봉사단,문씨,훈격,세종대왕,다문화가족,이주여성들,인식개선,...
# 13113  결의안,전세사기,본회의,피해자,인천시의회,미추홀구,인천,안상미,특별법,임시회,신성영...
# 13114  교직원,왕의지밀,전북대,양오봉,손의준,전북대학교,교직원들,관계자,관계자들,학생들,기...
# 13115  리베레츠시,체코,합창단,함평군,이상익,세베라첵,문화예술,협약식,국향대전,함평,도시간...
# 13116  하천점용료,용료,코로나19,점용,기본법,민간사업자,사업자,경제적,전경전남,화순군청,...
#
#                                                       본문  \
# 0      국내 자본시장 중계허브인 코스콤 STP-HUB가 가동 20주년을 앞두고 차세대 시스...
# 1      용인특례시의회 신현녀 의원, 용인시 통합 물관리 기본 조례 개정을 위한 정책간담회 ...
# 2      용인시정연구원(원장 이상대)은 25일 이슈리포트 'YRI Insight 제70호'를...
# 3      24일, 하남시의회 의원연구단체 지역 대표축제 발굴 육성을 위한 간담회 개최 하남시...
# 4      요즘 한국의 저출산이 심각한 사회문제라고 하는데요. 저출산으로 인한 인구구조 변화는...
# ...                                                  ...
# 13112  문미선 세종대왕 봉사단 회장 “낯선 환경에서 고군분투하는 이주여성에게 한글의 고유한...
# 13113  인천시의회가 최근 본회의에서 '주택 전세사기 대책 촉구 결의안' 처리를 보류해 인천...
# 13114  전북대학교와 한옥형 호텔인 왕의지밀은 19일 교직원의 복지 향상을 위한 업무 협약을...
# 13115  전남 함평군이 19일 체코 리베레츠시와 우호 교류 협약을 체결했다.왼쪽 두 번째 이...
# 13116  화순군청 전경전남 화순군이 지난해에 이어 코로나19 장기화로 인해 경제적인 어려움을...
#
#                                                      URL 분석제외 여부
# 0      http://www.dt.co.kr/contents.html?article_no=2...     NaN
# 1      http://www.joongdo.co.kr/web/view.php?key=2023...     NaN
# 2      http://www.joongdo.co.kr/web/view.php?key=2023...     NaN
# 3      http://www.joongdo.co.kr/web/view.php?key=2023...     NaN
# 4      https://www.hankyung.com/news/article/20230526...     NaN
# ...                                                  ...     ...
# 13112    https://www.kyeonggi.com/article/20230521580071     NaN
# 13113  http://www.kyeongin.com/main/view.php?key=2023...     NaN
# 13114         https://www.jjan.kr/article/20230520580012     NaN
# 13115  http://www.joongdo.co.kr/web/view.php?key=2023...     NaN
# 13116  http://www.joongdo.co.kr/web/view.php?key=2023...     NaN
#
# [13117 rows x 19 columns]

# %%
dates = [str(x)[0:4] + '-' + str(x)[4:6] + '-' + str(x)[6:8] for x in raw['일자']]

# %%
news = raw['본문']

# %%
urls =  raw['URL']

# %%
keywords = [x.split(',') for x in  raw['키워드']]

# %%
# h정보를 dataframe으로 만들고 저장.
data = pd.DataFrame({'date':dates,'news':news,'url':urls,'keyword':keywords})

name = "dataByDate_{}_{}.pickle".format(from_date,to_date)
name = name.replace('/','.')
with open(main_path + '/' + 'dataByDate/' + name,'wb') as f:
    pickle.dump(data,f)

# %%
# 키워드 카운트
DataCountByDay = pd.DataFrame(Counter(list(chain(*data['keyword'].values))),index = [from_date])

# %%
DataCountByDay = DataCountByDay.T

# %%
DataCountByDay
# Out:
#       2023-05-22
# 금융          8011
# 코스콤           16
# 자본          1083
# 시장          9746
# 중계            53
# ...          ...
# 점용허가           1
# 경작자            1
# 화군             1
# 하천법            1
# 제37조           1
#
# [131429 rows x 1 columns]

# %%
DataCountByDay.loc['부채한도']
# Out:
# 2023-05-22    212
# Name: 부채한도, dtype: int64

# %%
# 워드 클라우드
import matplotlib.pyplot as plt
from wordcloud import WordCloud
from matplotlib.pyplot import figure
from wordcloud import (WordCloud, get_single_color_func)
import numpy as np
def DrawPointColoredWC(tags,title,cwd,searching_word, drop_list=[], color = '#00ff00', pointed_list=[]):
    color_to_words = {
        color : pointed_list
    }

    use_tags = tags.drop(drop_list, errors = 'ignore')
    wc = WordCloud(font_path='C:/Windows/Fonts/malgun',background_color="white",width=1600, height=800,random_state = 1)

    default_color = 'black'
    grouped_color_func = GroupedColorFunc(color_to_words, default_color)

    cloud = wc.generate_from_frequencies(dict(use_tags))
    wc.recolor(color_func=grouped_color_func)

    figure(dpi=1200)
    figure(figsize=[12,8])
    plt.axis("off")
    plt.imshow(wc, interpolation="bilinear")
    plt.savefig(cwd + '/' + searching_word + '/'+ title + ' 강조'+'.pdf')
    plt.show()
    
class SimpleGroupedColorFunc(object):
    """Create a color function object which assigns EXACT colors
       to certain words based on the color to words mapping

       Parameters
       ----------
       color_to_words : dict(str -> list(str))
         A dictionary that maps a color to the list of words.

       default_color : str
         Color that will be assigned to a word that's not a member
         of any value from color_to_words.
    """

    def __init__(self, color_to_words, default_color):
        self.word_to_color = {word: color
                              for (color, words) in color_to_words.items()
                              for word in words}

        self.default_color = default_color

    def __call__(self, word, **kwargs):
        return self.word_to_color.get(word, self.default_color)


class GroupedColorFunc(object):
    """Create a color function object which assigns DIFFERENT SHADES of
       specified colors to certain words based on the color to words mapping.

       Uses wordcloud.get_single_color_func

       Parameters
       ----------
       color_to_words : dict(str -> list(str))
         A dictionary that maps a color to the list of words.

       default_color : str
         Color that will be assigned to a word that's not a member
         of any value from color_to_words.
    """

    def __init__(self, color_to_words, default_color):
        self.color_func_to_words = [
            (get_single_color_func(color), set(words))
            for (color, words) in color_to_words.items()]

        self.default_color_func = get_single_color_func(default_color)

    def get_color_func(self, word):
        """Returns a single_color_func associated with the word"""
        try:
            color_func = next(
                color_func for (color_func, words) in self.color_func_to_words
                if word in words)
        except StopIteration:
            color_func = self.default_color_func

        return color_func

    def __call__(self, word, **kwargs):
        return self.get_color_func(word)(word, **kwargs)

# %%
# 최대 키워드 수, 지울 단어, 강조할 단어 지정
num_exp = 50
drop_list = [np.nan,']
num = num_exp + len(drop_list)
color_to_words = {
    '#00ff00': []
}

# %%
'''
DataCountByDay = DataCountByDay.T
DataCountByDay['digital'] = 16
DataCountByDay['supply chain'] = 18
DataCountByDay = DataCountByDay.T
'''
# Out:
# "\nDataCountByDay = DataCountByDay.T\nDataCountByDay['digital'] = 16\nDataCountByDay['supply chain'] = 18\nDataCountByDay = DataCountByDay.T\n"

# %%
# 그림 그리기 및 저장
tags = DataCountByDay.sort_values(by = from_date, ascending = False)[1:num+1][from_date]
tags = tags.drop(drop_list, errors = 'ignore')[:num_exp]
print('{}에서 {}까지 키워드 출현 빈도 순 상위 {}개 입니다'.format(from_date,to_date,num_exp))
wc = WordCloud(font_path='C:/Windows/Fonts/malgun',background_color="white",width=1600, height=800,random_state = 1)
# default_color = 'black'
# grouped_color_func = GroupedColorFunc(color_to_words, default_color)

cloud = wc.generate_from_frequencies(dict(tags))
# wc.recolor(color_func=grouped_color_func)

figure(dpi=1200)
title = '대상기간_최대출현_키워드_{}개'.format(str(len(tags)))
plt.axis("off")
plt.imshow(wc, interpolation="bilinear")
plt.savefig(cwd + '/' + query + '/'+ title + from_date + '.pdf')
plt.show()
# Out:
# 2023-05-22에서 2023-05-29까지 키워드 출현 빈도 순 상위 50개 입니다
